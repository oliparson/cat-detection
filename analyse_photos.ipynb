# %%
# %matplotlib inline
from google.cloud import storage
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Download file from GCS bucket to notebook instance

client = storage.Client()
bucket = client.get_bucket('catflap-photos-raw')
blob = bucket.blob('image-old.jpg')
filepath = '/home/jupyter/images/image-old.jpg'
with open(filepath, 'wb') as file_obj:
    blob.download_to_file(file_obj)

# %%
# Open image and display it

img = mpimg.imread(filepath)
plt.imshow(img)

# %%
# Print shape of image (height x width x colours)

img.shape
# Out:
# (2464, 3280, 3)
